# %% [markdown]
# Navkaran Singh
# 3119008
# PHYS-2112- Scientific Computing with Python
# Assignment 10
#
# *late submission due to personal issues, discussed with the professor on email
# *due date was wednesday November 24th

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
# %reload_ext autoreload

# %%
# using built in data sets
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'taxis', 'tips', 'titanic']

# %%
planets_df = sns.load_dataset('planets')
planets_df
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
sns.histplot(planets_df['mass'], kde = True)
# Out:
# <AxesSubplot:xlabel='mass', ylabel='Count'>

# %%
# plotting a regression line
# on x axis : distance of the planet and on y-axis: mass of the planet
sns.jointplot(x='distance', y='mass', data = planets_df, kind = 'reg')

# %%
# plotting a kde
# on x axis : distance of the planet and on y-axis: mass of the planet
sns.jointplot(x='distance', y='mass', data = planets_df, kind = 'kde')

# %%
# kde plot for mass
sns.kdeplot(planets_df['mass'])
# Out:
# <AxesSubplot:xlabel='mass', ylabel='Density'>

# %%
# plotting a hexagon 
# on x axis : distance of the planet and on y-axis: mass of the planet
sns.jointplot(x='distance', y='mass', data = planets_df, kind = 'hex')

# %%
# pair plot 
sns.pairplot(planets_df)

# %%
crash_df = sns.load_dataset('car_crashes')
crash_df
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
#plotting where the person was drinking and driving
sns.displot(crash_df['alcohol'])

# %%
sns.pairplot(crash_df, hue='total', palette='Blues')

# %%
# rug plot
sns.rugplot(crash_df['alcohol'])
# Out:
# <AxesSubplot:xlabel='alcohol'>

# %%
exercise = sns.load_dataset('exercise')
df1 = exercise.tail()
df1
# Out:
#     Unnamed: 0  id    diet  pulse    time     kind
# 85          85  29  no fat    135  15 min  running
# 86          86  29  no fat    130  30 min  running
# 87          87  30  no fat     99   1 min  running
# 88          88  30  no fat    111  15 min  running
# 89          89  30  no fat    150  30 min  running

# %%
df2 = pd.DataFrame({'diet':['no fat'],'time':['15 min']})
df2
# Out:
#      diet    time
# 0  no fat  15 min
