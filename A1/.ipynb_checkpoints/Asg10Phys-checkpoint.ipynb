# %% [markdown]
# Gurparteek Singh
#
# PHYS-2112- Scientific Computing with Python

# %% [markdown]
# The list of URLs that i read from
#
# 1. https://github.com/wesm/pydata-book/blob/2nd-edition/ch14.ipynb
#
# 2. https://data.winnipeg.ca/Parking/Rush-Hour-Vehicle-Towing-Data/8phf-9kb6
#
# 3. https://www.youtube.com/playlist?list=PLYCpMb24GpOC704uO9svUrihl-HY1tTJJ
#
# 4. https://towardsdatascience.com/exploring-a-data-set-with-simple-pandas-and-plot-visualizations-features-73901ee76c6c
#
# 5. https://www.kaggle.com/kashnitsky/topic-1-exploratory-data-analysis-with-pandas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
data = pd.read_csv("https://data.winnipeg.ca/api/views/gp3k-am4u/rows.csv?accessType=DOWNLOAD")
data
# Out:
#             Row ID  Stop Number Route Number           Route Name  \
# 0        879279813        40684           40  All Seasons Express
# 1        879279815        40691           40  All Seasons Express
# 2        879279817        40705           40  All Seasons Express
# 3        879279819        40706           40  All Seasons Express
# 4        879279821        40724           40  All Seasons Express
# ...            ...          ...          ...                  ...
# 6131483  879094369        30390           77      Crosstown North
# 6131484  879096811        10581           11     Portage-Kildonan
# 6131485  879103077        10536           15     Sargent-Mountain
# 6131486  879103363        30042           18   North Main-Corydon
# 6131487  879103439        10142           18   North Main-Corydon
#
#                Route Destination Day Type          Scheduled Time  Deviation  \
# 0               Balmoral Station  Weekday  10/27/2021 06:27:00 AM       -198
# ...

# %% [markdown]
# This takes a long while to process

# %%
from urllib.request import urlretrieve

URL = 'https://data.winnipeg.ca/api/views/gp3k-am4u/rows.csv?accessType=DOWNLOAD'
urlretrieve(URL, 'R_transit.csv')
data1 = pd.read_csv('R_transit.csv')
data1.head()
# Out:
#       Row ID  Stop Number Route Number           Route Name Route Destination  \
# 0  879279813        40684           40  All Seasons Express  Balmoral Station
# 1  879279815        40691           40  All Seasons Express  Balmoral Station
# 2  879279817        40705           40  All Seasons Express  Balmoral Station
# 3  879279819        40706           40  All Seasons Express  Balmoral Station
# 4  879279821        40724           40  All Seasons Express  Balmoral Station
#
#   Day Type          Scheduled Time  Deviation  \
# 0  Weekday  10/27/2021 06:27:00 AM       -198
# 1  Weekday  10/27/2021 06:27:48 AM       -202
# 2  Weekday  10/27/2021 06:28:09 AM       -204
# 3  Weekday  10/27/2021 06:28:32 AM       -203
# 4  Weekday  10/27/2021 06:29:11 AM       -217
#
#                                    Location
# 0   POINT (-97.051829149428 49.94407541125)
# 1  POINT (-97.047108888212 49.942574791234)
# 2  POINT (-97.044607085401 49.942055890353)
# ...

# %% [markdown]
# This also took almost same amount of time to process, but after the first loading it is saved

# %%
data1 = pd.read_csv('R_transit.csv', index_col='Row ID')
data1.head()
# Out:
#            Stop Number Route Number           Route Name Route Destination  \
# Row ID
# 879279813        40684           40  All Seasons Express  Balmoral Station
# 879279815        40691           40  All Seasons Express  Balmoral Station
# 879279817        40705           40  All Seasons Express  Balmoral Station
# 879279819        40706           40  All Seasons Express  Balmoral Station
# 879279821        40724           40  All Seasons Express  Balmoral Station
#
#           Day Type          Scheduled Time  Deviation  \
# Row ID
# 879279813  Weekday  10/27/2021 06:27:00 AM       -198
# 879279815  Weekday  10/27/2021 06:27:48 AM       -202
# 879279817  Weekday  10/27/2021 06:28:09 AM       -204
# 879279819  Weekday  10/27/2021 06:28:32 AM       -203
# 879279821  Weekday  10/27/2021 06:29:11 AM       -217
#
#                                            Location
# Row ID
# 879279813   POINT (-97.051829149428 49.94407541125)
# 879279815  POINT (-97.047108888212 49.942574791234)
# ...

# %%
data1.tail()
# Out:
#            Stop Number Route Number          Route Name  \
# Row ID
# 879094369        30390           77     Crosstown North
# 879096811        10581           11    Portage-Kildonan
# 879103077        10536           15    Sargent-Mountain
# 879103363        30042           18  North Main-Corydon
# 879103439        10142           18  North Main-Corydon
#
#                  Route Destination Day Type          Scheduled Time  \
# Row ID
# 879094369           Kildonan Place  Weekday  10/26/2021 05:10:05 PM
# 879096811                  Glenway  Weekday  10/26/2021 02:40:58 PM
# 879103077  Airport via Flight Road  Weekday  10/26/2021 07:46:57 AM
# 879103363                   Tuxedo  Weekday  10/26/2021 02:58:18 PM
# 879103439                   Tuxedo  Weekday  10/26/2021 03:39:27 PM
#
#            Deviation                                  Location
# Row ID
# 879094369         42  POINT (-97.160862076723 49.949418028781)
# 879096811        -46  POINT (-97.147575796734 49.892025477559)
# ...

# %%
data1.head(69)
# Out:
#            Stop Number Route Number           Route Name  \
# Row ID
# 879279813        40684           40  All Seasons Express
# 879279815        40691           40  All Seasons Express
# 879279817        40705           40  All Seasons Express
# 879279819        40706           40  All Seasons Express
# 879279821        40724           40  All Seasons Express
# ...                ...          ...                  ...
# 871901996        30348           32   North Main Express
# 879279933        60400           66                Grant
# 879279935        60398           66                Grant
# 879279937        60396           66                Grant
# 879279939        60394           66                Grant
#
#               Route Destination Day Type          Scheduled Time  Deviation  \
# Row ID
# 879279813      Balmoral Station  Weekday  10/27/2021 06:27:00 AM       -198
# 879279815      Balmoral Station  Weekday  10/27/2021 06:27:48 AM       -202
# ...

# %%
data1.tail(69)
# Out:
#            Stop Number Route Number          Route Name  \
# Row ID
# 879047094        40644           11    Portage-Kildonan
# 879056593        30503           77     Crosstown North
# 879052271        60730           78            Waverley
# 879051947        10386           78            Waverley
# 879048389        40378           11    Portage-Kildonan
# ...                ...          ...                 ...
# 879094369        30390           77     Crosstown North
# 879096811        10581           11    Portage-Kildonan
# 879103077        10536           15    Sargent-Mountain
# 879103363        30042           18  North Main-Corydon
# 879103439        10142           18  North Main-Corydon
#
#                  Route Destination Day Type          Scheduled Time  \
# Row ID
# 879047094                Polo Park  Weekday  10/26/2021 10:01:00 AM
# 879056593                Polo Park  Weekday  10/26/2021 03:47:39 PM
# ...

# %%
data1['Route Number'].tail()
# Out:
# Row ID
# 879094369    77
# 879096811    11
# 879103077    15
# 879103363    18
# 879103439    18
# Name: Route Number, dtype: object

# %%
data1.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Stop Number'}>,
#         <AxesSubplot:title={'center':'Deviation'}>]], dtype=object)

# %%
data1.plot()
# Out:
# <AxesSubplot:xlabel='Row ID'>
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# ~\miniconda3\lib\site-packages\matplotlib\backends\backend_agg.py in draw_path(self, gc, path, transform, rgbFace)
#     160             try:
# --> 161                 self._renderer.draw_path(gc, path, transform, rgbFace)
#     162             except OverflowError as err:
#
# OverflowError: In draw_path: Exceeded cell block limit
#
# The above exception was the direct cause of the following exception:
#
# OverflowError                             Traceback (most recent call last)
# ~\miniconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ...

# %%
#data1.groupby('Route Destination').hist()
#this cause a lot of memory consumption on my pc almost 90% usage
# Out:
# C:\Users\Nav\miniconda3\lib\site-packages\pandas\plotting\_matplotlib\tools.py:218: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(**fig_kw)
# Route Destination
# Airport Terminal                      [[AxesSubplot(0.125,0.125;0.336957x0.755), Axe...
# Airport via Flight Road               [[AxesSubplot(0.125,0.125;0.336957x0.755), Axe...
# Airport via Wellington                [[AxesSubplot(0.125,0.125;0.336957x0.755), Axe...
# Aldgate                               [[AxesSubplot(0.125,0.125;0.336957x0.755), Axe...
# All Seasons                           [[AxesSubplot(0.125,0.125;0.336957x0.755), Axe...
#                                                             ...
# ...

# %%
data.describe
# Out:
# <bound method NDFrame.describe of             Row ID  Stop Number Route Number          Route Name  \
# 0        878741419        30379           18  North Main-Corydon
# 1        878741421        30363           18  North Main-Corydon
# 2        878741423        30374           18  North Main-Corydon
# 3        878741425        30393           18  North Main-Corydon
# 4        878741427        30394           18  North Main-Corydon
# ...            ...          ...          ...                 ...
# 5974598  879096811        10581           11    Portage-Kildonan
# 5974599  879103077        10536           15    Sargent-Mountain
# 5974600  879103363        30042           18  North Main-Corydon
# 5974601  879103439        10142           18  North Main-Corydon
# 5974602  879087165        60712           74            Kenaston
#
#                Route Destination Day Type          Scheduled Time  Deviation  \
# ...

# %%
data1.loc[data1['Route Destination'] == 'Polo Park']
# Out:
#            Stop Number Route Number        Route Name Route Destination  \
# Row ID
# 879285560        40404           11  Portage-Kildonan         Polo Park
# 879285562        40405           11  Portage-Kildonan         Polo Park
# 879285564        40406           11  Portage-Kildonan         Polo Park
# 879285566        40407           11  Portage-Kildonan         Polo Park
# 879285568        40408           11  Portage-Kildonan         Polo Park
# ...                ...          ...               ...               ...
# 879083748        30505           77   Crosstown North         Polo Park
# 879083784        30639           77   Crosstown North         Polo Park
# 879084462        20003           77   Crosstown North         Polo Park
# 879084473        10823           77   Crosstown North         Polo Park
# 879092942        30621           77   Crosstown North         Polo Park
#
#           Day Type          Scheduled Time  Deviation  \
# Row ID
# ...

# %%
data1[data1['Route Destination'] == 'Kildonan Place'].count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_30076/482503315.py in <module>
# ----> 1 data1[data1['Route Destination'] == 'Kildonan Place'].count()
#
# NameError: name 'data1' is not defined

# %%
data1[data1['Route Destination'] == 'Polo Park'].count()

# %% [markdown]
# Here's the another data set

# %%
URL='https://data.winnipeg.ca/api/views/mer2-irmb/rows.csv?accessType=DOWNLOAD'
urlretrieve(URL,'Fremont.csv')
data2 = pd.read_csv('Fremont.csv')
data2.head()
# Out:
#    Pass-Up ID      Pass-Up Type                    Time Route Number  \
# 0     3054784  Full Bus Pass-Up  11/23/2019 07:30:06 PM           11
# 1     3054854  Full Bus Pass-Up  11/24/2019 09:49:15 AM          170
# 2     3055024  Full Bus Pass-Up  11/24/2019 04:02:09 PM           11
# 3     3055083  Full Bus Pass-Up  11/24/2019 06:35:54 PM           11
# 4     3054785  Full Bus Pass-Up  11/23/2019 07:30:14 PM           11
#
#                     Route Name Route Destination  \
# 0             Portage-Kildonan       Via Glenway
# 1  Fort Richmond - St. Norbert       To Downtown
# 2             Portage-Kildonan      To Polo Park
# 3             Portage-Kildonan       Via Donwood
# 4             Portage-Kildonan       Via Glenway
#
#                                    Location
# 0   POINT (-97.188800279492 49.88243163641)
# 1   POINT (-97.151684893085 49.81759394067)
# 2   POINT (-97.150726428724 49.89119427188)
# 3  POINT (-97.196676428673 49.881016294322)
# ...

# %%
data2.tail()
# Out:
#         Pass-Up ID             Pass-Up Type                    Time  \
# 142727     3340214         Full Bus Pass-Up  11/21/2021 10:35:18 AM
# 142728     3340212         Full Bus Pass-Up  11/21/2021 10:26:01 AM
# 142729     3340738  Wheelchair User Pass-Up  11/22/2021 04:56:31 PM
# 142730     3340682         Full Bus Pass-Up  11/22/2021 03:52:45 PM
# 142731     3340675         Full Bus Pass-Up  11/22/2021 03:45:06 PM
#
#        Route Number           Route Name       Route Destination  \
# 142727           11     Portage-Kildonan            Via Westwood
# 142728           47  Transcona - Pembina              Via Regent
# 142729           16      Selkirk-Osborne            Via Manitoba
# 142730          672            Killarney          Prairie Pointe
# 142731           44                 Grey  To Downtown via London
#
#                                         Location
# 142727  POINT (-97.156735642426 49.889149170422)
# 142728   POINT (-97.10548484067 49.904828767566)
# ...

# %%
data2.groupby('W').plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25212/2628733582.py in <module>
# ----> 1 data2.groupby('W').plot()
#
# ~\miniconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7629         # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7630         # "Union[bool, NoDefault]"; expected "bool"
# -> 7631         return DataFrameGroupBy(
#    7632             obj=self,
#    7633             keys=by,
#
# ~\miniconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     887             from pandas.core.groupby.grouper import get_grouper
#     888
# ...

# %%
data2.groupby('Y').plot()

# %%
data2.resample('W').sum().plot()

# %% [markdown]
# Data 3 using US baby names 1880-2010

# %%
URL2='https://data.winnipeg.ca/api/views/8phf-9kb6/rows.csv?accessType=DOWNLOAD'
urlretrieve(URL2,'Fremont.csv')
data3 = pd.read_csv('Fremont.csv',index_col='Request Date', parse_dates=True)
data3.head()
# Out:
#                      Location Pickup    Cross Streets Pickup   Status  \
# Request Date
# 2020-09-09 15:32:00     Sherbrook ST       E/S WILLIAM ELGIN  Cleared
# 2020-09-09 15:33:00  Westminster AVE  N/S SHERBROOK MARYLAND  Cleared
# 2020-10-21 16:42:00         York AVE     N/S VAUGHAN KENNEDY  Cleared
# 2020-11-05 07:02:00         Broadway     N/S BALMORAL SPENCE  Cleared
# 2020-11-26 17:21:00      Maryland ST      E/S ELLICE PORTAGE  Cleared
#
#                                    GPS Pickup
# Request Date
# 2020-09-09 15:32:00  POINT (-97.1552 49.9048)
# 2020-09-09 15:33:00    POINT (-97.16 49.8819)
# 2020-10-21 16:42:00  POINT (-97.1475 49.8881)
# 2020-11-05 07:02:00  POINT (-97.1534 49.8857)
# 2020-11-26 17:21:00  POINT (-97.1604 49.8904)

# %%
def get_least10(group):
    return group.sort_values(by='Status', ascending=True)[:10]
grouped = data.groupby('Request Date')
top10 = grouped.apply(get_least10)
